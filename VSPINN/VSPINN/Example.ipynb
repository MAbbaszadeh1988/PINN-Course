# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x,w):
  return np.exp(-w*x**2)

x = np.linspace(-2, 2, 1000)
fig = plt.figure(figsize=(4,2))
plt.plot(x,f(x,1000))

# %%
x = np.linspace(-2, 2, 1000)
fig = plt.figure(figsize=(4,2))
plt.plot(x,f(x,1))
